# %% [markdown]
# # Step 8 - Champion ML Model and Governance
#
# Official notebook wrapper for the Step 8 evidence and retraining entry point.
#
# - Champion single model: LightGBM v3
# - Calibrated benchmark: Weighted ensemble with Platt calibration
# - Final evidence directory: `outputs/final/`
# - Source of truth: `docs/METRICS_SOURCE_OF_TRUTH.csv`
#
# This notebook does not install packages automatically. Install dependencies before running:
#
# ```bash
# pip install -r requirements-lock.txt
# ```

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src' / 'step08_train_champion_v3.py').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT / 'src'))
PROJECT_ROOT

# %% [markdown]
# ## Fast Evidence Rebuild
#
# Use this mode for portfolio review, CI validation, and quick reproducibility checks. It rebuilds canonical tables from committed evidence.

# %%
import subprocess

subprocess.run([
    sys.executable,
    str(PROJECT_ROOT / 'src' / 'step08_train_champion_v3.py'),
    '--mode',
    'evidence',
], cwd=PROJECT_ROOT, check=True)

# %% [markdown]
# ## Optional Full Retrain
#
# This mode trains the LightGBM v3-style champion from `data/processed/final_customer_analysis_train.csv.gz`. Exact metrics can vary with package versions and hardware.

# %%
# Uncomment to retrain.
# subprocess.run([
#     sys.executable,
#     str(PROJECT_ROOT / 'src' / 'step08_train_champion_v3.py'),
#     '--mode',
#     'train',
# ], cwd=PROJECT_ROOT, check=True)

# %% [markdown]
# ## Published Metric Evidence
#
# The README and model cards should be audited against the generated canonical files, especially:
#
# - `outputs/final/champion_validation_metrics.csv`
# - `outputs/final/model_comparison.csv`
# - `outputs/final/decision_bands.csv`
# - `outputs/final/dashboard_rule_segments.csv`
# - `docs/METRICS_SOURCE_OF_TRUTH.csv`
